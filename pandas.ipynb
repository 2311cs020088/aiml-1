# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv("universities.csv")
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df1[(df1["GradRate"]>=95)]
# Out:
#          Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 5   Dartmouth  1340     89      23       10     32162        95
# 6        Duke  1315     90      30       12     31585        95
# 8     Harvard  1400     91      14       11     39525        97
# 14  Princeton  1375     91      14        8     30220        95
# 24       Yale  1375     95      19       11     43514        96

# %%
df1.sort_values(ascending=False,by="SFRatio")
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 17      TexasA&M  1075     49      67       25      8704        67
# 15        Purdue  1005     28      90       19      9066        69
# 13     PennState  1081     38      54       18     10185        80
# 18    UCBerkeley  1240     95      40       17     15140        78
# 20     UMichigan  1180     65      68       16     15470        85
# 23    UWisconsin  1085     40      69       15     11857        71
# 22           UVA  1225     77      44       14     13349        92
# 0          Brown  1310     89      22       13     22704        94
# 19      UChicago  1290     75      50       13     38380        87
# 12     NotreDame  1255     81      42       13     15122        94
# 4        Cornell  1280     83      33       13     21864        90
# 16      Stanford  1360     90      20       12     36450        93
# 7     Georgetown  1255     74      24       12     20126        92
# ...

# %% [markdown]
# #### Salaries ####

# %%
sal = pd.read_csv("salaries.csv")
sal
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   20       20    Male  122400
# 2   AssocProf          A   20       17    Male   81285
# 3        Prof          B   23       23    Male  134778
# 4    AsstProf          B    1        0    Male   88000
# 5        Prof          B   17        3    Male  150480
# 6    AsstProf          B    8        3    Male   75044
# 7    AsstProf          B    4        0    Male   92000
# 8        Prof          A   19        7    Male  107300
# 9        Prof          A   29       27    Male  150500
# 10   AsstProf          B    4        4    Male   92000
# 11       Prof          A   33       30    Male  103106
# 12   AsstProf          A    4        2    Male   73000
# 13   AsstProf          A    2        0    Male   85000
# 14       Prof          A   30       23    Male   91100
# 15   AsstProf          B    7        2    Male   91300
# ...

# %%
sal["salary"].groupby(sal["rank"]).mean()
# Out:
# rank
# AssocProf     93270.777778
# AsstProf      82260.500000
# Prof         125561.615385
# Name: salary, dtype: float64

# %%
sal[["salary","phd","service"]].groupby(sal["rank"]).median()
# Out:
#              salary   phd  service
# rank
# AssocProf  103613.0  12.0      9.0
# AsstProf    81750.0   4.0      3.0
# Prof       123041.5  23.5     19.5

# %%
sal[["salary","phd","service"]].groupby(sal["rank"]).mean()
# Out:
#                   salary        phd    service
# rank
# AssocProf   93270.777778  14.888889  11.111111
# AsstProf    82260.500000   5.312500   2.500000
# Prof       125561.615385  26.307692  20.038462

# %%
import pandas as pd

# %%
data = {
    'User ID' : [1, 1, 2, 2, 3, 3, 4, 3, 7],
    'Moive Name' : ['Avatar', 'Inception', 'Titanic', 'Inception', 'Avatar', 'Inception', 'Avatar', 'Titanic', 'Inception'],
    'Rating':[9,8,10,8,9,7,9,10,8]
}

# %%
df = pd.DataFrame(data)

# %%
pivot_table = df.pivot(index='User ID', columns='Moive Name', values='Rating')
print(pivot_table)
# Out:
# Moive Name  Avatar  Inception  Titanic
# User ID
# 1              9.0        8.0      NaN
# 2              NaN        8.0     10.0
# 3              9.0        7.0     10.0
# 4              9.0        NaN      NaN
# 7              NaN        8.0      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
plt.title("Acceptance Ratio")
plt.hist(df1["Accept"])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Visualization using boxplot ####

# %%
#create a pandas series of batmen1 score
s1 = [20,15,10,25,30,35,28,40,45,60]
scores1 = pd.Series(s1)
scores1
# Out:
# 0    20
# 1    15
# 2    10
# 3    25
# 4    30
# 5    35
# 6    28
# 7    40
# 8    45
# 9    60
# dtype: int64

# %%
plt.figure(figsize=(6,2))
plt.title("Boxplot for batsman scores")
plt.xlabel("Scores")
plt.boxplot(scores1, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x164c02809e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x164c0281130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x164c0246510>],
#  'medians': [<matplotlib.lines.Line2D at 0x164c0281610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x164c02818e0>],
#  'means': []}

# %%
#Add extreme values to scores and plot the boxplot
s2 = [20,15,10,25,30,35,28,40,45,60,120,150]
scores2 = pd.Series(s2)
print(scores2)

plt.figure(figsize=(6,2))
plt.title("Boxplot for batsman scores")
plt.xlabel("Scores")
plt.boxplot(scores2, vert=False)
# Out:
# 0      20
# 1      15
# 2      10
# 3      25
# 4      30
# 5      35
# 6      28
# 7      40
# 8      45
# 9      60
# 10    120
# 11    150
# dtype: int64
# {'whiskers': [<matplotlib.lines.Line2D at 0x164c0aab740>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x164c0aabcb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x164c0aab4d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x164c0ae81a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x164c0ae83b0>],
#  'means': []}

# %%
#Add extreme values to scores and plot the boxplot
s3 = [20,15,10,25,30,35,28,40,45,80,120,150]
scores3 = pd.Series(s3)
print(scores3)

plt.figure(figsize=(6,2))
plt.title("Boxplot for batsman scores")
plt.xlabel("Scores")
plt.boxplot(scores3, vert=False)
# Out:
# 0      20
# 1      15
# 2      10
# 3      25
# 4      30
# 5      35
# 6      28
# 7      40
# 8      45
# 9      80
# 10    120
# 11    150
# dtype: int64
# {'whiskers': [<matplotlib.lines.Line2D at 0x164c1ed6630>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x164c1ed6ae0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x164c1ed63c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x164c1ed70e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x164c1ed73b0>],
#  'means': []}
